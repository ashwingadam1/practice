# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
from ggplot import *
import IPython.display as display
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from sklearn.preprocessing import StandardScaler
from sklearn.cross_validation import train_test_split
from __future__ import division
from __future__ import division
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import KFold, cross_val_score
from sklearn.metrics import confusion_matrix,precision_recall_curve,auc,roc_auc_score,roc_curve,recall_score,classification_report 
# %matplotlib inline
# Out:
# /home/ashwin/anaconda2/lib/python2.7/site-packages/ggplot/utils.py:81: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access Timestamp as pandas.Timestamp
#   pd.tslib.Timestamp,
# /home/ashwin/anaconda2/lib/python2.7/site-packages/ggplot/stats/smoothers.py:4: FutureWarning: The pandas.lib module is deprecated and will be removed in a future version. These are private functions and can be accessed from pandas._libs.lib instead
#   from pandas.lib import Timestamp
# /home/ashwin/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
data=pd.read_csv('/home/ashwin/Downloads/credit/creditcard.csv')
data.describe()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Time</th>
#       <th>V1</th>
#       <th>V2</th>
#       <th>V3</th>
#       <th>V4</th>
#       <th>V5</th>
#       <th>V6</th>
#       <th>V7</th>
#       <th>V8</th>
#       <th>V9</th>
#       <th>...</th>
#       <th>V21</th>
#       <th>V22</th>
#       <th>V23</th>
#       <th>V24</th>
#       <th>V25</th>
#       <th>V26</th>
#       <th>V27</th>
#       <th>V28</th>
#       <th>Amount</th>
#       <th>Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>284807.000000</td>
#       <td>2.848070e+05</td>
#       <td>2.848070e+05</td>
#       <td>2.848070e+05</td>
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
# Time      284807 non-null float64
# V1        284807 non-null float64
# V2        284807 non-null float64
# V3        284807 non-null float64
# V4        284807 non-null float64
# V5        284807 non-null float64
# V6        284807 non-null float64
# V7        284807 non-null float64
# V8        284807 non-null float64
# V9        284807 non-null float64
# V10       284807 non-null float64
# V11       284807 non-null float64
# V12       284807 non-null float64
# V13       284807 non-null float64
# V14       284807 non-null float64
# V15       284807 non-null float64
# V16       284807 non-null float64
# V17       284807 non-null float64
# V18       284807 non-null float64
# V19       284807 non-null float64
# V20       284807 non-null float64
# V21       284807 non-null float64
# V22       284807 non-null float64
# V23       284807 non-null float64
# ...

# %%
data['Class'].plot(kind='hist')

# %%
print list(data)
# Out:
# ['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']

# %%
data.groupby('Class').nunique()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Time</th>
#       <th>V1</th>
#       <th>V2</th>
#       <th>V3</th>
#       <th>V4</th>
#       <th>V5</th>
#       <th>V6</th>
#       <th>V7</th>
#       <th>V8</th>
#       <th>V9</th>
#       <th>...</th>
#       <th>V21</th>
#       <th>V22</th>
#       <th>V23</th>
#       <th>V24</th>
#       <th>V25</th>
#       <th>V26</th>
#       <th>V27</th>
#       <th>V28</th>
#       <th>Amount</th>
#       <th>Class</th>
#     </tr>
#     <tr>
#       <th>Class</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
# ...

# %%
data['normAmount']=StandardScaler().fit_transform(data['Amount'].reshape(-1,1))
# Out:
# /home/ashwin/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """Entry point for launching an IPython kernel.

# %%
data=data.drop(['Time','Amount'],axis=1)
data.shape
# Out:
# (284807, 30)

# %%
y=data['Class']
x=data.drop('Class',axis=1)

# %%
ros=RandomOverSampler(random_state=0)
x_resampled,y_resampled=ros.fit_sample(x,y)
print (sorted(Counter(y_resampled).items()))
print x_resampled.shape
# Out:
# [(0, 284315), (1, 284315)]
# (568630, 29)

# %%
x_train,x_test,y_train,y_test=\
    train_test_split(x,y,test_size=0.3,random_state=0)
print 'the size of the x train of actual data is',len(x_train)
print 'the size of the y train of actual data is',len(y_train)
print 'the size of the x test of actual data is',len(x_test)
print 'the size of the y test of actual data is',len(y_test)

x_resample_train,x_resample_test,y_resample_train,y_resample_test=\
    train_test_split(x_resampled,y_resampled,test_size=0.3,random_state=0)
print 'the size of the x train of resampled data is',len(x_resample_train)
print 'the size of the y train of resampled data is',len(y_resample_train)
print 'the size of the x test of resampled data is',len(x_resample_test)
print 'the size of the y test of resampled data is',len(y_resample_test)
# Out:
# the size of the x train of actual data is 199364
# the size of the y train of actual data is 199364
# the size of the x test of actual data is 85443
# the size of the y test of actual data is 85443
# the size of the x train of resampled data is 398041
# the size of the y train of resampled data is 398041
# the size of the x test of resampled data is 170589
# the size of the y test of resampled data is 170589

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=0)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    else:
        1#print('Confusion matrix, without normalization')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def acc_def(model):
    acc=cross_val_score(model, x_resample_train, y_resample_train,
                        cv=10,scoring='recall')
    return acc

# %%
c_vaal=[0.01,0.1,1,10,100]
log_reg=[acc_def(LogisticRegression(C=c,penalty = 'l2',n_jobs=-1))
                 .mean() for c in c_vaal]

# %%
print log_reg
# Out:
# [0.91903319380931026, 0.92081816349444168, 0.92100419597470695, 0.92100419597470695, 0.92100419597470695]

# %%
logrig=LogisticRegression(C=0.1,penalty = 'l2',n_jobs=-1)
logrig.fit(x_resample_train, y_resample_train)
over_pred=logrig.predict(x_resample_test)
recall_acc=recall_score(y_resample_test,over_pred)

# %%
recall_acc
# Out:
# 0.92342358160386739

# %%
logrig1=LogisticRegression(C=0.1,penalty = 'l2',n_jobs=-1)
logrig1.fit(x_train, y_train)
over_pred1=logrig1.predict(x_test)
recall_acc1=recall_score(y_test,over_pred1)

# %%
recall_acc1
# Out:
# 0.59863945578231292

# %%
predict_on_val=logrig.predict(x_test)

# %%
con_mat=confusion_matrix(y_test,predict_on_val)
np.set_printoptions(precision=2)
print("Recall metric in the testing dataset: ", con_mat[1,1]/(con_mat[1,0]+con_mat[1,1]))
# Plot non-normalized confusion matrix
class_names = [0,1]
plt.figure()
plot_confusion_matrix(con_mat
                      , classes=class_names
                      , title='Confusion matrix')
plt.show()
# Out:
# ('Recall metric in the testing dataset: ', 0.92517006802721091)

# %%
preds = logrig.predict_proba(x_test)[:,1]
fpr, tpr, sc = roc_curve(y_test, preds)

df = pd.DataFrame(dict(fpr=fpr, tpr=tpr))
ggplot(df, aes(x='fpr', y='tpr')) +\
    geom_line() +\
    geom_abline(linetype='dashed')
# Out:
# <ggplot: (8756376843537)>
